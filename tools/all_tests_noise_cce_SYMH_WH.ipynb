# %%
using PyPlot
using LaTeXStrings
using DelimitedFiles
pygui(true)

# %%
# give the directory where the data from all the runs are saved
your_dir = "/home/thanasis/repos/model_CCE_CCM_public/examples/run_cce/"

# %%
# CCE SYMH-WH L2-L2 test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_WH_noise_t20_L2_amp/norms_exact_cauchy_char"

# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
tt_0                        = readdlm(test_dir*res, comments=true)[:,1]
L2_L2_cauchy_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
L2_L2_char_sol_0            = readdlm(test_dir*res, comments=true)[:,3]
L2_L2_cauchy_given_0        = readdlm(test_dir*res, comments=true)[:,4]
L2_L2_char_given_0          = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/L2_1.dat"
L2_L2_cauchy_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
L2_L2_char_sol_1            = readdlm(test_dir*res, comments=true)[:,3]
L2_L2_cauchy_given_1        = readdlm(test_dir*res, comments=true)[:,4]
L2_L2_char_given_1          = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/L2_2.dat"
L2_L2_cauchy_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
L2_L2_char_sol_2            = readdlm(test_dir*res, comments=true)[:,3]
L2_L2_cauchy_given_2        = readdlm(test_dir*res, comments=true)[:,4]
L2_L2_char_given_2          = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/L2_3.dat"
L2_L2_cauchy_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
L2_L2_char_sol_3            = readdlm(test_dir*res, comments=true)[:,3]
L2_L2_cauchy_given_3        = readdlm(test_dir*res, comments=true)[:,4]
L2_L2_char_given_3          = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/L2_4.dat"
L2_L2_cauchy_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
L2_L2_char_sol_4            = readdlm(test_dir*res, comments=true)[:,3]
L2_L2_cauchy_given_4        = readdlm(test_dir*res, comments=true)[:,4]
L2_L2_char_given_4          = readdlm(test_dir*res, comments=true)[:,5];

# %%
# CCE SYMH-WH q-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_WH_noise_t20_q_amp/dev_norms_exact_cauchy_char"

# the first q is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
q_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
q_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3]
q_q_cauchy_given_0          = readdlm(test_dir*res, comments=true)[:,6]
q_q_char_given_0            = readdlm(test_dir*res, comments=true)[:,7]

#N=1
res = "/norms_1.dat"
q_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
q_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3]
q_q_cauchy_given_1          = readdlm(test_dir*res, comments=true)[:,6]
q_q_char_given_1            = readdlm(test_dir*res, comments=true)[:,7]

#N=2
res = "/norms_2.dat"
q_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
q_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3]
q_q_cauchy_given_2          = readdlm(test_dir*res, comments=true)[:,6]
q_q_char_given_2            = readdlm(test_dir*res, comments=true)[:,7]

#N=3
res = "/norms_3.dat"
q_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
q_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3]
q_q_cauchy_given_3          = readdlm(test_dir*res, comments=true)[:,6]
q_q_char_given_3            = readdlm(test_dir*res, comments=true)[:,7]

#N=4
res = "/norms_4.dat"
q_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
q_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3]
q_q_cauchy_given_4          = readdlm(test_dir*res, comments=true)[:,6]
q_q_char_given_4            = readdlm(test_dir*res, comments=true)[:,7];

# %%
# CCE SYMH-WH H1-H1 test, and H1-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_WH_noise_t20_H1_amp/dev_norms_exact_cauchy_char"

# the first H1 is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
H1_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2] # test 4
H1_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3] # test 4
H1_H1_cauchy_sol_0           = readdlm(test_dir*res, comments=true)[:,4]
H1_H1_char_sol_0             = readdlm(test_dir*res, comments=true)[:,5]
H1_H1_cauchy_given_0         = readdlm(test_dir*res, comments=true)[:,8]
H1_H1_char_given_0           = readdlm(test_dir*res, comments=true)[:,9]

#N=1
res = "/norms_1.dat"
H1_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2] # test 4
H1_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3] # test 4
H1_H1_cauchy_sol_1           = readdlm(test_dir*res, comments=true)[:,4]
H1_H1_char_sol_1             = readdlm(test_dir*res, comments=true)[:,5]
H1_H1_cauchy_given_1         = readdlm(test_dir*res, comments=true)[:,8]
H1_H1_char_given_1           = readdlm(test_dir*res, comments=true)[:,9]

#N=2
res = "/norms_2.dat"
H1_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2] # test 4
H1_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3] # test 4
H1_H1_cauchy_sol_2           = readdlm(test_dir*res, comments=true)[:,4]
H1_H1_char_sol_2             = readdlm(test_dir*res, comments=true)[:,5]
H1_H1_cauchy_given_2         = readdlm(test_dir*res, comments=true)[:,8]
H1_H1_char_given_2           = readdlm(test_dir*res, comments=true)[:,9]

#N=3
res = "/norms_3.dat"
H1_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2] # test 4
H1_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3] # test 4
H1_H1_cauchy_sol_3           = readdlm(test_dir*res, comments=true)[:,4]
H1_H1_char_sol_3             = readdlm(test_dir*res, comments=true)[:,5]
H1_H1_cauchy_given_3         = readdlm(test_dir*res, comments=true)[:,8]
H1_H1_char_given_3           = readdlm(test_dir*res, comments=true)[:,9]

#N=4
res = "/norms_4.dat"
H1_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2] # test 4
H1_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3] # test 4
H1_H1_cauchy_sol_4           = readdlm(test_dir*res, comments=true)[:,4]
H1_H1_char_sol_4             = readdlm(test_dir*res, comments=true)[:,5]
H1_H1_cauchy_given_4         = readdlm(test_dir*res, comments=true)[:,8]
H1_H1_char_given_4           = readdlm(test_dir*res, comments=true)[:,9];

# %%
## IBVP L2-L2, q-q, H1-H1, and H1-q tests, for solution ##

fig = figure("pyplot_subplot_touching",figsize=(7.5,6))
subplots_adjust(hspace=0.12, wspace=0.09, top = 0.949, bottom = 0.105, right=0.975, left=0.085)# Set the vertical spacing between axes

# IBVP L2-L2 test
subplot(221)
title(L"L^2-L^2"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_sol_0)./sqrt.(L2_L2_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_sol_1)./sqrt.(L2_L2_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_sol_2)./sqrt.(L2_L2_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_sol_3)./sqrt.(L2_L2_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# IBVP q-q test
subplot(222)
title(L"q-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(q_q_cauchy_sol_0)./sqrt.(q_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_sol_1)./sqrt.(q_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_sol_2)./sqrt.(q_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_sol_3)./sqrt.(q_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=9)
###############################

# IBVP H1-H1 test
subplot(223)
title(L"H_1-H_1"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_sol_0)./sqrt.(H1_H1_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H_1}\,/\,||\mathbf{u_1}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_sol_1)./sqrt.(H1_H1_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H_1}\,/\,||\mathbf{u_1}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_sol_2)./sqrt.(H1_H1_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H_1}\,/ \,||\mathbf{u_1}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_sol_3)./sqrt.(H1_H1_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H_1}\,/ \,||\mathbf{u_1}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# IBVP H1-q test
subplot(224)
title(L"H_1-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_q_cauchy_sol_0)./sqrt.(H1_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_cauchy_sol_1)./sqrt.(H1_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_cauchy_sol_2)./sqrt.(H1_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_cauchy_sol_3)./sqrt.(H1_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
## IBVP L2-L2, q-q, and H1-H1 tests, for given data ##

fig = figure("pyplot_subplot_touching",figsize=(10,3))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.985, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# IBVP given data test 1
subplot(131)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_given_0)./sqrt.(L2_L2_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_given_1)./sqrt.(L2_L2_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_given_2)./sqrt.(L2_L2_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_cauchy_given_3)./sqrt.(L2_L2_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# IBVP given data test 2
subplot(132)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(q_q_cauchy_given_0)./sqrt.(q_q_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_given_1)./sqrt.(q_q_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_given_2)./sqrt.(q_q_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_cauchy_given_3)./sqrt.(q_q_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# IBVP given data test 3
subplot(133)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="0")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_given_0)./sqrt.(H1_H1_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H_1}\,/\,||\mathbf{u_1}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_given_1)./sqrt.(H1_H1_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H_1}\,/\,||\mathbf{u_1}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_given_2)./sqrt.(H1_H1_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H_1}\,/ \,||\mathbf{u_1}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_cauchy_given_3)./sqrt.(H1_H1_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H_1}\,/ \,||\mathbf{u_1}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################


fig.canvas.draw() # Update the figure

# %%
#initial data only
println(log2.(sqrt.(H1_H1_cauchy_given_0)./sqrt.(H1_H1_cauchy_given_1))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_1)./sqrt.(H1_H1_cauchy_given_2))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_2)./sqrt.(H1_H1_cauchy_given_3))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_3)./sqrt.(H1_H1_cauchy_given_4))[1])

println(log2.(sqrt.(H1_H1_cauchy_given_0)./sqrt.(H1_H1_cauchy_given_1))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_1)./sqrt.(H1_H1_cauchy_given_2))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_2)./sqrt.(H1_H1_cauchy_given_3))[1])
println(log2.(sqrt.(H1_H1_cauchy_given_3)./sqrt.(H1_H1_cauchy_given_4))[1])

# %%
## CIBVP L2-L2, q-q, H1-H1, and H1-q tests, for solution ##

fig = figure("pyplot_subplot_touching",figsize=(7.5,6))
subplots_adjust(hspace=0.12, wspace=0.09, top = 0.949, bottom = 0.105, right=0.975, left=0.085)# Set the vertical spacing between axes

# CIBVP L2-L2 test
subplot(221)
title(L"L^2-L^2"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(L2_L2_char_sol_0)./sqrt.(L2_L2_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_sol_1)./sqrt.(L2_L2_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_sol_2)./sqrt.(L2_L2_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_sol_3)./sqrt.(L2_L2_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="12", loc=9)
###############################

# CIBVP q-q test
subplot(222)
title(L"q-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(q_q_char_sol_0)./sqrt.(q_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_sol_1)./sqrt.(q_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_sol_2)./sqrt.(q_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_sol_3)./sqrt.(q_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="12", loc=9)
###############################

# CIBVP H1-H1 test
subplot(223)
title(L"H_1-H_1"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_H1_char_sol_0)./sqrt.(H1_H1_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H_1}\,/\,||\mathbf{u_2}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_sol_1)./sqrt.(H1_H1_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H_1}\,/\,||\mathbf{u_2}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_sol_2)./sqrt.(H1_H1_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H_1}\,/ \,||\mathbf{u_2}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_sol_3)./sqrt.(H1_H1_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H_1}\,/ \,||\mathbf{u_2}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="12", loc=9)
###############################

# CIBVP H1-q test
subplot(224)
title(L"H_1-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_q_char_sol_0)./sqrt.(H1_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_char_sol_1)./sqrt.(H1_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_char_sol_2)./sqrt.(H1_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(H1_q_char_sol_3)./sqrt.(H1_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="12", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
## CIBVP L2-L2, q-q, and H1-H1 tests, for given data ##

fig = figure("pyplot_subplot_touching",figsize=(10,3))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.985, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# CIBVP given data L2-L2 test
subplot(131)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(L2_L2_char_given_0)./sqrt.(L2_L2_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_given_1)./sqrt.(L2_L2_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_given_2)./sqrt.(L2_L2_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(L2_L2_char_given_3)./sqrt.(L2_L2_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# CIBVP given data q-q test
subplot(132)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(q_q_char_given_0)./sqrt.(q_q_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_given_1)./sqrt.(q_q_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_given_2)./sqrt.(q_q_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(q_q_char_given_3)./sqrt.(q_q_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=9)
###############################

# CIBVP given data H1-H1 test
subplot(133)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="0")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(H1_H1_char_given_0)./sqrt.(H1_H1_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H1}\,/\,||\mathbf{u_2}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_given_1)./sqrt.(H1_H1_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H1}\,/\,||\mathbf{u_2}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_given_2)./sqrt.(H1_H1_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H1}\,/ \,||\mathbf{u_2}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(H1_H1_char_given_3)./sqrt.(H1_H1_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H1}\,/ \,||\mathbf{u_2}_{h_4}||_{H1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################


fig.canvas.draw() # Update the figure
