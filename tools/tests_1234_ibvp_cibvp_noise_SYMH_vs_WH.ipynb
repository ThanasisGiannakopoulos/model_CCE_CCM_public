# %%
using PyPlot
using LaTeXStrings
using DelimitedFiles
pygui(true)

# %%
# give the directory where the data from all the runs are saved
your_dir = "/home/thanasis/repos/model_CCE_CCM_public/examples/run_ibvp_cibvp/"

# %%
# SYMH test 1
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_SYMH_noise_t20_L2_amp/norms_exact_cauchy_char"

# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
tt_0                             = readdlm(test_dir*res, comments=true)[:,1]
SYMH_L2_L2_cauchy_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_L2_L2_char_sol_0            = readdlm(test_dir*res, comments=true)[:,3]
SYMH_L2_L2_cauchy_given_0        = readdlm(test_dir*res, comments=true)[:,4]
SYMH_L2_L2_char_given_0          = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/L2_1.dat"
tt_1                             = readdlm(test_dir*res, comments=true)[:,1]
SYMH_L2_L2_cauchy_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_L2_L2_char_sol_1            = readdlm(test_dir*res, comments=true)[:,3]
SYMH_L2_L2_cauchy_given_1        = readdlm(test_dir*res, comments=true)[:,4]
SYMH_L2_L2_char_given_1          = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/L2_2.dat"
tt_2                             = readdlm(test_dir*res, comments=true)[:,1]
SYMH_L2_L2_cauchy_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_L2_L2_char_sol_2            = readdlm(test_dir*res, comments=true)[:,3]
SYMH_L2_L2_cauchy_given_2        = readdlm(test_dir*res, comments=true)[:,4]
SYMH_L2_L2_char_given_2          = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/L2_3.dat"
tt_3                             = readdlm(test_dir*res, comments=true)[:,1]
SYMH_L2_L2_cauchy_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_L2_L2_char_sol_3            = readdlm(test_dir*res, comments=true)[:,3]
SYMH_L2_L2_cauchy_given_3        = readdlm(test_dir*res, comments=true)[:,4]
SYMH_L2_L2_char_given_3          = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/L2_4.dat"
tt_4                             = readdlm(test_dir*res, comments=true)[:,1]
SYMH_L2_L2_cauchy_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_L2_L2_char_sol_4            = readdlm(test_dir*res, comments=true)[:,3]
SYMH_L2_L2_cauchy_given_4        = readdlm(test_dir*res, comments=true)[:,4]
SYMH_L2_L2_char_given_4          = readdlm(test_dir*res, comments=true)[:,5];

# %%
# SYMH test 2
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_SYMH_noise_t20_q_amp/dev_norms_exact_cauchy_char"

# the first q is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
SYMH_q_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_q_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3]
SYMH_q_q_cauchy_given_0          = readdlm(test_dir*res, comments=true)[:,6]
SYMH_q_q_char_given_0            = readdlm(test_dir*res, comments=true)[:,7]

#N=1
res = "/norms_1.dat"
SYMH_q_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_q_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3]
SYMH_q_q_cauchy_given_1          = readdlm(test_dir*res, comments=true)[:,6]
SYMH_q_q_char_given_1            = readdlm(test_dir*res, comments=true)[:,7]

#N=2
res = "/norms_2.dat"
SYMH_q_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_q_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3]
SYMH_q_q_cauchy_given_2          = readdlm(test_dir*res, comments=true)[:,6]
SYMH_q_q_char_given_2            = readdlm(test_dir*res, comments=true)[:,7]

#N=3
res = "/norms_3.dat"
SYMH_q_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_q_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3]
SYMH_q_q_cauchy_given_3          = readdlm(test_dir*res, comments=true)[:,6]
SYMH_q_q_char_given_3            = readdlm(test_dir*res, comments=true)[:,7]

#N=4
res = "/norms_4.dat"
SYMH_q_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_q_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3]
SYMH_q_q_cauchy_given_4          = readdlm(test_dir*res, comments=true)[:,6]
SYMH_q_q_char_given_4            = readdlm(test_dir*res, comments=true)[:,7];

# %%
# SYMH tests 3, 4
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_SYMH_noise_t20_H1_amp/dev_norms_exact_cauchy_char"

# the first H1 is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
SYMH_H1_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2] # test 4
SYMH_H1_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3] # test 4
SYMH_H1_H1_cauchy_sol_0           = readdlm(test_dir*res, comments=true)[:,4]
SYMH_H1_H1_char_sol_0             = readdlm(test_dir*res, comments=true)[:,5]
SYMH_H1_H1_cauchy_given_0         = readdlm(test_dir*res, comments=true)[:,8]
SYMH_H1_H1_char_given_0           = readdlm(test_dir*res, comments=true)[:,9]

#N=1
res = "/norms_1.dat"
SYMH_H1_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2] # test 4
SYMH_H1_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3] # test 4
SYMH_H1_H1_cauchy_sol_1           = readdlm(test_dir*res, comments=true)[:,4]
SYMH_H1_H1_char_sol_1             = readdlm(test_dir*res, comments=true)[:,5]
SYMH_H1_H1_cauchy_given_1         = readdlm(test_dir*res, comments=true)[:,8]
SYMH_H1_H1_char_given_1           = readdlm(test_dir*res, comments=true)[:,9]

#N=2
res = "/norms_2.dat"
SYMH_H1_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2] # test 4
SYMH_H1_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3] # test 4
SYMH_H1_H1_cauchy_sol_2           = readdlm(test_dir*res, comments=true)[:,4]
SYMH_H1_H1_char_sol_2             = readdlm(test_dir*res, comments=true)[:,5]
SYMH_H1_H1_cauchy_given_2         = readdlm(test_dir*res, comments=true)[:,8]
SYMH_H1_H1_char_given_2           = readdlm(test_dir*res, comments=true)[:,9]

#N=3
res = "/norms_3.dat"
SYMH_H1_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2] # test 4
SYMH_H1_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3] # test 4
SYMH_H1_H1_cauchy_sol_3           = readdlm(test_dir*res, comments=true)[:,4]
SYMH_H1_H1_char_sol_3             = readdlm(test_dir*res, comments=true)[:,5]
SYMH_H1_H1_cauchy_given_3         = readdlm(test_dir*res, comments=true)[:,8]
SYMH_H1_H1_char_given_3           = readdlm(test_dir*res, comments=true)[:,9]

#N=4
res = "/norms_4.dat"
SYMH_H1_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2] # test 4
SYMH_H1_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3] # test 4
SYMH_H1_H1_cauchy_sol_4           = readdlm(test_dir*res, comments=true)[:,4]
SYMH_H1_H1_char_sol_4             = readdlm(test_dir*res, comments=true)[:,5]
SYMH_H1_H1_cauchy_given_4         = readdlm(test_dir*res, comments=true)[:,8]
SYMH_H1_H1_char_given_4           = readdlm(test_dir*res, comments=true)[:,9];

# %%
# WH test 1
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"WH_WH_noise_t20_L2_amp/norms_exact_cauchy_char"

# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
WH_L2_L2_cauchy_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
WH_L2_L2_char_sol_0            = readdlm(test_dir*res, comments=true)[:,3]
WH_L2_L2_cauchy_given_0        = readdlm(test_dir*res, comments=true)[:,4]
WH_L2_L2_char_given_0          = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/L2_1.dat"
WH_L2_L2_cauchy_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
WH_L2_L2_char_sol_1            = readdlm(test_dir*res, comments=true)[:,3]
WH_L2_L2_cauchy_given_1        = readdlm(test_dir*res, comments=true)[:,4]
WH_L2_L2_char_given_1          = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/L2_2.dat"
WH_L2_L2_cauchy_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
WH_L2_L2_char_sol_2            = readdlm(test_dir*res, comments=true)[:,3]
WH_L2_L2_cauchy_given_2        = readdlm(test_dir*res, comments=true)[:,4]
WH_L2_L2_char_given_2          = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/L2_3.dat"
WH_L2_L2_cauchy_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
WH_L2_L2_char_sol_3            = readdlm(test_dir*res, comments=true)[:,3]
WH_L2_L2_cauchy_given_3        = readdlm(test_dir*res, comments=true)[:,4]
WH_L2_L2_char_given_3          = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/L2_4.dat"
WH_L2_L2_cauchy_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
WH_L2_L2_char_sol_4            = readdlm(test_dir*res, comments=true)[:,3]
WH_L2_L2_cauchy_given_4        = readdlm(test_dir*res, comments=true)[:,4]
WH_L2_L2_char_given_4          = readdlm(test_dir*res, comments=true)[:,5];

# %%
# WH test 2
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"WH_WH_noise_t20_q_amp/dev_norms_exact_cauchy_char"

# the first q is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
WH_q_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
WH_q_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3]
WH_q_q_cauchy_given_0          = readdlm(test_dir*res, comments=true)[:,6]
WH_q_q_char_given_0            = readdlm(test_dir*res, comments=true)[:,7]

#N=1
res = "/norms_1.dat"
WH_q_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
WH_q_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3]
WH_q_q_cauchy_given_1          = readdlm(test_dir*res, comments=true)[:,6]
WH_q_q_char_given_1            = readdlm(test_dir*res, comments=true)[:,7]

#N=2
res = "/norms_2.dat"
WH_q_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
WH_q_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3]
WH_q_q_cauchy_given_2          = readdlm(test_dir*res, comments=true)[:,6]
WH_q_q_char_given_2            = readdlm(test_dir*res, comments=true)[:,7]

#N=3
res = "/norms_3.dat"
WH_q_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
WH_q_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3]
WH_q_q_cauchy_given_3          = readdlm(test_dir*res, comments=true)[:,6]
WH_q_q_char_given_3            = readdlm(test_dir*res, comments=true)[:,7]

#N=4
res = "/norms_4.dat"
WH_q_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
WH_q_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3]
WH_q_q_cauchy_given_4          = readdlm(test_dir*res, comments=true)[:,6]
WH_q_q_char_given_4            = readdlm(test_dir*res, comments=true)[:,7];

# %%
# WH tests 3, 4
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"WH_WH_noise_t20_H1_amp/dev_norms_exact_cauchy_char"

# the first H1 is for the given data and the second for the solution

#N=0
res = "/norms_0.dat"
WH_H1_q_cauchy_sol_0            = readdlm(test_dir*res, comments=true)[:,2] # test 4
WH_H1_q_char_sol_0              = readdlm(test_dir*res, comments=true)[:,3] # test 4
WH_H1_H1_cauchy_sol_0           = readdlm(test_dir*res, comments=true)[:,4]
WH_H1_H1_char_sol_0             = readdlm(test_dir*res, comments=true)[:,5]
WH_H1_H1_cauchy_given_0         = readdlm(test_dir*res, comments=true)[:,8]
WH_H1_H1_char_given_0           = readdlm(test_dir*res, comments=true)[:,9]

#N=1
res = "/norms_1.dat"
WH_H1_q_cauchy_sol_1            = readdlm(test_dir*res, comments=true)[:,2] # test 4
WH_H1_q_char_sol_1              = readdlm(test_dir*res, comments=true)[:,3] # test 4
WH_H1_H1_cauchy_sol_1           = readdlm(test_dir*res, comments=true)[:,4]
WH_H1_H1_char_sol_1             = readdlm(test_dir*res, comments=true)[:,5]
WH_H1_H1_cauchy_given_1         = readdlm(test_dir*res, comments=true)[:,8]
WH_H1_H1_char_given_1           = readdlm(test_dir*res, comments=true)[:,9]

#N=2
res = "/norms_2.dat"
WH_H1_q_cauchy_sol_2            = readdlm(test_dir*res, comments=true)[:,2] # test 4
WH_H1_q_char_sol_2              = readdlm(test_dir*res, comments=true)[:,3] # test 4
WH_H1_H1_cauchy_sol_2           = readdlm(test_dir*res, comments=true)[:,4]
WH_H1_H1_char_sol_2             = readdlm(test_dir*res, comments=true)[:,5]
WH_H1_H1_cauchy_given_2         = readdlm(test_dir*res, comments=true)[:,8]
WH_H1_H1_char_given_2           = readdlm(test_dir*res, comments=true)[:,9]

#N=3
res = "/norms_3.dat"
WH_H1_q_cauchy_sol_3            = readdlm(test_dir*res, comments=true)[:,2] # test 4
WH_H1_q_char_sol_3              = readdlm(test_dir*res, comments=true)[:,3] # test 4
WH_H1_H1_cauchy_sol_3           = readdlm(test_dir*res, comments=true)[:,4]
WH_H1_H1_char_sol_3             = readdlm(test_dir*res, comments=true)[:,5]
WH_H1_H1_cauchy_given_3         = readdlm(test_dir*res, comments=true)[:,8]
WH_H1_H1_char_given_3           = readdlm(test_dir*res, comments=true)[:,9]

#N=4
res = "/norms_4.dat"
WH_H1_q_cauchy_sol_4            = readdlm(test_dir*res, comments=true)[:,2] # test 4
WH_H1_q_char_sol_4              = readdlm(test_dir*res, comments=true)[:,3] # test 4
WH_H1_H1_cauchy_sol_4           = readdlm(test_dir*res, comments=true)[:,4]
WH_H1_H1_char_sol_4             = readdlm(test_dir*res, comments=true)[:,5]
WH_H1_H1_cauchy_given_4         = readdlm(test_dir*res, comments=true)[:,8]
WH_H1_H1_char_given_4           = readdlm(test_dir*res, comments=true)[:,9];

# %%
## IBVP tests 1, 2, 3, for solution ##

fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.955, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# IBVP SYMH test 1
subplot(241) # Create the 1st fig in 2 rows and 2 columns
title("Test 1", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_sol_0)./sqrt.(SYMH_L2_L2_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_sol_1)./sqrt.(SYMH_L2_L2_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_sol_2)./sqrt.(SYMH_L2_L2_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_sol_3)./sqrt.(SYMH_L2_L2_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# IBVP WH test 1
subplot(245)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_sol_0)./sqrt.(WH_L2_L2_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_sol_1)./sqrt.(WH_L2_L2_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_sol_2)./sqrt.(WH_L2_L2_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_sol_3)./sqrt.(WH_L2_L2_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# IBVP SYMH test 2
subplot(242) # Create the 1st fig in 2 rows and 2 columns
title("Test 2", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_sol_0)./sqrt.(SYMH_q_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_sol_1)./sqrt.(SYMH_q_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_sol_2)./sqrt.(SYMH_q_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_sol_3)./sqrt.(SYMH_q_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=9)
################################

# IBVP WH test 2
subplot(246)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_sol_0)./sqrt.(WH_q_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_sol_1)./sqrt.(WH_q_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_sol_2)./sqrt.(WH_q_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_sol_3)./sqrt.(WH_q_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# IBVP SYMH test 3
subplot(243) # Create the 1st fig in 2 rows and 2 columns
title("Test 3", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_sol_0)./sqrt.(SYMH_H1_H1_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H1}\,/\,||\mathbf{u_1}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_sol_1)./sqrt.(SYMH_H1_H1_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H1}\,/\,||\mathbf{u_1}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_sol_2)./sqrt.(SYMH_H1_H1_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H1}\,/ \,||\mathbf{u_1}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_sol_3)./sqrt.(SYMH_H1_H1_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H1}\,/ \,||\mathbf{u_1}_{h_4}||_{H1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# IBVP WH test 3
subplot(247)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_sol_0)./sqrt.(WH_H1_H1_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H1}\,/\,||\mathbf{u_1}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_sol_1)./sqrt.(WH_H1_H1_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H1}\,/\,||\mathbf{u_1}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_sol_2)./sqrt.(WH_H1_H1_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H1}\,/ \,||\mathbf{u_1}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_sol_3)./sqrt.(WH_H1_H1_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H1}\,/ \,||\mathbf{u_1}_{h_4}||_{H1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

# IBVP SYMH test 4
subplot(244) # Create the 1st fig in 2 rows and 2 columns
title("Test 4", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_q_cauchy_sol_0)./sqrt.(SYMH_H1_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_cauchy_sol_1)./sqrt.(SYMH_H1_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_cauchy_sol_2)./sqrt.(SYMH_H1_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_cauchy_sol_3)./sqrt.(SYMH_H1_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# IBVP WH test 4
subplot(248)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_q_cauchy_sol_0)./sqrt.(WH_H1_q_cauchy_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_cauchy_sol_1)./sqrt.(WH_H1_q_cauchy_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_cauchy_sol_2)./sqrt.(WH_H1_q_cauchy_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_cauchy_sol_3)./sqrt.(WH_H1_q_cauchy_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
## IBVP tests 1, 2, 3, for given data ##
fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.985, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# IBVP SYMH test 1
subplot(231) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_given_0)./sqrt.(SYMH_L2_L2_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_given_1)./sqrt.(SYMH_L2_L2_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_given_2)./sqrt.(SYMH_L2_L2_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_cauchy_given_3)./sqrt.(SYMH_L2_L2_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# IBVP WH test 1
subplot(234)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_given_0)./sqrt.(WH_L2_L2_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{L^2}\,/\,||\mathbf{u_1}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_given_1)./sqrt.(WH_L2_L2_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{L^2}\,/\,||\mathbf{u_1}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_given_2)./sqrt.(WH_L2_L2_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{L^2}\,/ \,||\mathbf{u_1}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_cauchy_given_3)./sqrt.(WH_L2_L2_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{L^2}\,/ \,||\mathbf{u_1}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# IBVP SYMH test 2
subplot(232) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_given_0)./sqrt.(SYMH_q_q_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_given_1)./sqrt.(SYMH_q_q_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_given_2)./sqrt.(SYMH_q_q_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_cauchy_given_3)./sqrt.(SYMH_q_q_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=9)
################################

# IBVP WH test 2
subplot(235)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_given_0)./sqrt.(WH_q_q_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{q}\,/\,||\mathbf{u_1}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_given_1)./sqrt.(WH_q_q_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{q}\,/\,||\mathbf{u_1}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_given_2)./sqrt.(WH_q_q_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{q}\,/ \,||\mathbf{u_1}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_cauchy_given_3)./sqrt.(WH_q_q_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{q}\,/ \,||\mathbf{u_1}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
###############################

# IBVP SYMH test 3
subplot(233) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_given_0)./sqrt.(SYMH_H1_H1_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H1}\,/\,||\mathbf{u_1}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_given_1)./sqrt.(SYMH_H1_H1_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H1}\,/\,||\mathbf{u_1}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_given_2)./sqrt.(SYMH_H1_H1_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H1}\,/ \,||\mathbf{u_1}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_cauchy_given_3)./sqrt.(SYMH_H1_H1_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H1}\,/ \,||\mathbf{u_1}_{h_4}||_{H1}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# IBVP WH test 3
subplot(236)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_given_0)./sqrt.(WH_H1_H1_cauchy_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_1}_{h_0}||_{H1}\,/\,||\mathbf{u_1}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_given_1)./sqrt.(WH_H1_H1_cauchy_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_1}_{h_1}||_{H1}\,/\,||\mathbf{u_1}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_given_2)./sqrt.(WH_H1_H1_cauchy_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_1}_{h_2}||_{H1}\,/ \,||\mathbf{u_1}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_cauchy_given_3)./sqrt.(WH_H1_H1_cauchy_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_1}_{h_3}||_{H1}\,/ \,||\mathbf{u_1}_{h_4}||_{H1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
#initial data only
println(log2.(sqrt.(SYMH_H1_H1_cauchy_given_0)./sqrt.(SYMH_H1_H1_cauchy_given_1))[1])
println(log2.(sqrt.(SYMH_H1_H1_cauchy_given_1)./sqrt.(SYMH_H1_H1_cauchy_given_2))[1])
println(log2.(sqrt.(SYMH_H1_H1_cauchy_given_2)./sqrt.(SYMH_H1_H1_cauchy_given_3))[1])
println(log2.(sqrt.(SYMH_H1_H1_cauchy_given_3)./sqrt.(SYMH_H1_H1_cauchy_given_4))[1])

println(log2.(sqrt.(WH_H1_H1_cauchy_given_0)./sqrt.(WH_H1_H1_cauchy_given_1))[1])
println(log2.(sqrt.(WH_H1_H1_cauchy_given_1)./sqrt.(WH_H1_H1_cauchy_given_2))[1])
println(log2.(sqrt.(WH_H1_H1_cauchy_given_2)./sqrt.(WH_H1_H1_cauchy_given_3))[1])
println(log2.(sqrt.(WH_H1_H1_cauchy_given_3)./sqrt.(WH_H1_H1_cauchy_given_4))[1])

# %%
## CIBVP tests 1,2,3 for solution ##

fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.955, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# CIBVP SYMH test 1
subplot(241) # Create the 1st fig in 2 rows and 2 columns
title("Test 1", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_sol_0)./sqrt.(SYMH_L2_L2_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_sol_1)./sqrt.(SYMH_L2_L2_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_sol_2)./sqrt.(SYMH_L2_L2_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_sol_3)./sqrt.(SYMH_L2_L2_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CIBVP WH test 1
subplot(245)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_sol_0)./sqrt.(WH_L2_L2_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_sol_1)./sqrt.(WH_L2_L2_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_sol_2)./sqrt.(WH_L2_L2_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_sol_3)./sqrt.(WH_L2_L2_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# CIBVP SYMH test 2
subplot(242) # Create the 1st fig in 2 rows and 2 columns
title("Test 2", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_sol_0)./sqrt.(SYMH_q_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_sol_1)./sqrt.(SYMH_q_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_sol_2)./sqrt.(SYMH_q_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_sol_3)./sqrt.(SYMH_q_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=8)
################################

# CIBVP WH test 2
subplot(246)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_q_q_char_sol_0)./sqrt.(WH_q_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_sol_1)./sqrt.(WH_q_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_sol_2)./sqrt.(WH_q_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_sol_3)./sqrt.(WH_q_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# CIBVP SYMH test 3
subplot(243) # Create the 1st fig in 2 rows and 2 columns
title("Test 3", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_sol_0)./sqrt.(SYMH_H1_H1_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H1}\,/\,||\mathbf{u_2}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_sol_1)./sqrt.(SYMH_H1_H1_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H1}\,/\,||\mathbf{u_2}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_sol_2)./sqrt.(SYMH_H1_H1_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H1}\,/ \,||\mathbf{u_2}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_sol_3)./sqrt.(SYMH_H1_H1_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H1}\,/ \,||\mathbf{u_2}_{h_4}||_{H1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CIBVP WH test 3
subplot(247)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_sol_0)./sqrt.(WH_H1_H1_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H1}\,/\,||\mathbf{u_2}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_sol_1)./sqrt.(WH_H1_H1_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H1}\,/\,||\mathbf{u_2}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_sol_2)./sqrt.(WH_H1_H1_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H1}\,/ \,||\mathbf{u_2}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_sol_3)./sqrt.(WH_H1_H1_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H1}\,/ \,||\mathbf{u_2}_{h_4}||_{H1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

# CIBVP SYMH test 4
subplot(244) # Create the 1st fig in 2 rows and 2 columns
title("Test 4", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_q_char_sol_0)./sqrt.(SYMH_H1_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_char_sol_1)./sqrt.(SYMH_H1_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_char_sol_2)./sqrt.(SYMH_H1_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_q_char_sol_3)./sqrt.(SYMH_H1_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CIBVP WH test 4
subplot(248)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_q_char_sol_0)./sqrt.(WH_H1_q_char_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_char_sol_1)./sqrt.(WH_H1_q_char_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_char_sol_2)./sqrt.(WH_H1_q_char_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_q_char_sol_3)./sqrt.(WH_H1_q_char_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
## CIBVP tests 1,2,3 for given data ##

fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.985, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes
# CIBVP SYMH test 1
subplot(231) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_given_0)./sqrt.(SYMH_L2_L2_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_given_1)./sqrt.(SYMH_L2_L2_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_given_2)./sqrt.(SYMH_L2_L2_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_L2_L2_char_given_3)./sqrt.(SYMH_L2_L2_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# CIBVP WH test 1
subplot(234)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_given_0)./sqrt.(WH_L2_L2_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{L^2}\,/\,||\mathbf{u_2}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_given_1)./sqrt.(WH_L2_L2_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{L^2}\,/\,||\mathbf{u_2}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_given_2)./sqrt.(WH_L2_L2_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{L^2}\,/ \,||\mathbf{u_2}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_L2_L2_char_given_3)./sqrt.(WH_L2_L2_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{L^2}\,/ \,||\mathbf{u_2}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# CIBVP SYMH test 2
subplot(232) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_given_0)./sqrt.(SYMH_q_q_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_given_1)./sqrt.(SYMH_q_q_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_given_2)./sqrt.(SYMH_q_q_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_q_q_char_given_3)./sqrt.(SYMH_q_q_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=8)
################################

# CIBVP WH test 2
subplot(235)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_q_q_char_given_0)./sqrt.(WH_q_q_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{q}\,/\,||\mathbf{u_2}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_given_1)./sqrt.(WH_q_q_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{q}\,/\,||\mathbf{u_2}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_given_2)./sqrt.(WH_q_q_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{q}\,/ \,||\mathbf{u_2}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_q_q_char_given_3)./sqrt.(WH_q_q_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{q}\,/ \,||\mathbf{u_2}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
###############################

# CIBVP SYMH test 3
subplot(233) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_given_0)./sqrt.(SYMH_H1_H1_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H1}\,/\,||\mathbf{u_2}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_given_1)./sqrt.(SYMH_H1_H1_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H1}\,/\,||\mathbf{u_2}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_given_2)./sqrt.(SYMH_H1_H1_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H1}\,/ \,||\mathbf{u_2}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_H1_H1_char_given_3)./sqrt.(SYMH_H1_H1_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H1}\,/ \,||\mathbf{u_2}_{h_4}||_{H1}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# CIBVP WH test 3
subplot(236)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_given_0)./sqrt.(WH_H1_H1_char_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u_2}_{h_0}||_{H1}\,/\,||\mathbf{u_2}_{h_1}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_given_1)./sqrt.(WH_H1_H1_char_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u_2}_{h_1}||_{H1}\,/\,||\mathbf{u_2}_{h_2}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_given_2)./sqrt.(WH_H1_H1_char_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u_2}_{h_2}||_{H1}\,/ \,||\mathbf{u_2}_{h_3}||_{H1}\right)}")
plot(tt_0, log2.(sqrt.(WH_H1_H1_char_given_3)./sqrt.(WH_H1_H1_char_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u_2}_{h_3}||_{H1}\,/ \,||\mathbf{u_2}_{h_4}||_{H1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
# initial data only
println(log2.(sqrt.(SYMH_H1_H1_char_given_0)./sqrt.(SYMH_H1_H1_char_given_1))[1])
println(log2.(sqrt.(SYMH_H1_H1_char_given_1)./sqrt.(SYMH_H1_H1_char_given_2))[1])
println(log2.(sqrt.(SYMH_H1_H1_char_given_2)./sqrt.(SYMH_H1_H1_char_given_3))[1])
println(log2.(sqrt.(SYMH_H1_H1_char_given_3)./sqrt.(SYMH_H1_H1_char_given_4))[1])

println(log2.(sqrt.(WH_H1_H1_char_given_0)./sqrt.(WH_H1_H1_char_given_1))[1])
println(log2.(sqrt.(WH_H1_H1_char_given_1)./sqrt.(WH_H1_H1_char_given_2))[1])
println(log2.(sqrt.(WH_H1_H1_char_given_2)./sqrt.(WH_H1_H1_char_given_3))[1])
println(log2.(sqrt.(WH_H1_H1_char_given_3)./sqrt.(WH_H1_H1_char_given_4))[1])
