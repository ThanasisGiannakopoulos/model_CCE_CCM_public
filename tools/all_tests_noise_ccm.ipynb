# %%
using PyPlot
using LaTeXStrings
using DelimitedFiles
pygui(true)

# %%
# give the directory where the data from all the runs are saved
your_dir = "/home/thanasis/repos/model_CCE_CCM_public/examples/run_ccm/"

# %%
# SYMH_SYMH L2-L2 test
test_dir = your_dir*"SYMH_SYMH_noise_t20_L2_amp/norms_exact"
# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
tt_0                           = readdlm(test_dir*res, comments=true)[:,1]
SYMH_SYMH_L2_L2_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_L2_L2_given_0        = readdlm(test_dir*res, comments=true)[:,3]

#N=1
res = "/L2_1.dat"
tt_1                           = readdlm(test_dir*res, comments=true)[:,1]
SYMH_SYMH_L2_L2_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_L2_L2_given_1        = readdlm(test_dir*res, comments=true)[:,3]

#N=2
res = "/L2_2.dat"
tt_2                           = readdlm(test_dir*res, comments=true)[:,1]
SYMH_SYMH_L2_L2_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_L2_L2_given_2        = readdlm(test_dir*res, comments=true)[:,3]

#N=3
res = "/L2_3.dat"
tt_3                           = readdlm(test_dir*res, comments=true)[:,1]
SYMH_SYMH_L2_L2_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_L2_L2_given_3        = readdlm(test_dir*res, comments=true)[:,3]

#N=4
res = "/L2_4.dat"
tt_4                           = readdlm(test_dir*res, comments=true)[:,1]
SYMH_SYMH_L2_L2_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_L2_L2_given_4        = readdlm(test_dir*res, comments=true)[:,3];

# %%
# SYMH SYMH q-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_SYMH_noise_t20_q_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_SYMH_q_q_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_q_q_given_0          = readdlm(test_dir*res, comments=true)[:,4]

#N=1
res = "/dev_norms_1.dat"
SYMH_SYMH_q_q_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_q_q_given_1          = readdlm(test_dir*res, comments=true)[:,4]

#N=2
res = "/dev_norms_2.dat"
SYMH_SYMH_q_q_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_q_q_given_2          = readdlm(test_dir*res, comments=true)[:,4]

#N=3
res = "/dev_norms_3.dat"
SYMH_SYMH_q_q_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_q_q_given_3          = readdlm(test_dir*res, comments=true)[:,4]

#N=4
res = "/dev_norms_4.dat"
SYMH_SYMH_q_q_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_q_q_given_4          = readdlm(test_dir*res, comments=true)[:,4];

# %%
# SYMH SYMH H1-H1, and H1-q tests
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_SYMH_noise_t20_H1_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_SYMH_H1_q_sol_0           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_H1_H1_sol_0          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_SYMH_H1_q_given_0         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_SYMH_H1_H1_given_0        = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/dev_norms_1.dat"
SYMH_SYMH_H1_q_sol_1           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_H1_H1_sol_1          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_SYMH_H1_q_given_1         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_SYMH_H1_H1_given_1        = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/dev_norms_2.dat"
SYMH_SYMH_H1_q_sol_2           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_H1_H1_sol_2          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_SYMH_H1_q_given_2         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_SYMH_H1_H1_given_2        = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/dev_norms_3.dat"
SYMH_SYMH_H1_q_sol_3           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_H1_H1_sol_3          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_SYMH_H1_q_given_3         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_SYMH_H1_H1_given_3        = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/dev_norms_4.dat"
SYMH_SYMH_H1_q_sol_4           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_SYMH_H1_H1_sol_4          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_SYMH_H1_q_given_4         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_SYMH_H1_H1_given_4        = readdlm(test_dir*res, comments=true)[:,5];

# %%
# WH_WH L2-L2 test
test_dir = your_dir*"WH_WH_noise_t20_L2_amp/norms_exact"
# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
WH_WH_L2_L2_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_L2_L2_given_0        = readdlm(test_dir*res, comments=true)[:,3]

#N=1
res = "/L2_1.dat"
WH_WH_L2_L2_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_L2_L2_given_1        = readdlm(test_dir*res, comments=true)[:,3]

#N=2
res = "/L2_2.dat"
WH_WH_L2_L2_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_L2_L2_given_2        = readdlm(test_dir*res, comments=true)[:,3]

#N=3
res = "/L2_3.dat"
WH_WH_L2_L2_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_L2_L2_given_3        = readdlm(test_dir*res, comments=true)[:,3]

#N=4
res = "/L2_4.dat"
WH_WH_L2_L2_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_L2_L2_given_4        = readdlm(test_dir*res, comments=true)[:,3];

# %%
# WH_WH q-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"WH_WH_noise_t20_q_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
WH_WH_q_q_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_q_q_given_0          = readdlm(test_dir*res, comments=true)[:,4]

#N=1
res = "/dev_norms_1.dat"
WH_WH_q_q_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_q_q_given_1          = readdlm(test_dir*res, comments=true)[:,4]

#N=2
res = "/dev_norms_2.dat"
WH_WH_q_q_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_q_q_given_2          = readdlm(test_dir*res, comments=true)[:,4]

#N=3
res = "/dev_norms_3.dat"
WH_WH_q_q_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_q_q_given_3          = readdlm(test_dir*res, comments=true)[:,4]

#N=4
res = "/dev_norms_4.dat"
WH_WH_q_q_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_q_q_given_4          = readdlm(test_dir*res, comments=true)[:,4];

# %%
# WH_WH H1-H1, and H1-q tests
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"WH_WH_noise_t20_H1_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
WH_WH_H1_q_sol_0           = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_H1_H1_sol_0          = readdlm(test_dir*res, comments=true)[:,3]
WH_WH_H1_q_given_0         = readdlm(test_dir*res, comments=true)[:,4]
WH_WH_H1_H1_given_0        = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/dev_norms_1.dat"
WH_WH_H1_q_sol_1           = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_H1_H1_sol_1          = readdlm(test_dir*res, comments=true)[:,3]
WH_WH_H1_q_given_1         = readdlm(test_dir*res, comments=true)[:,4]
WH_WH_H1_H1_given_1        = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/dev_norms_2.dat"
WH_WH_H1_q_sol_2           = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_H1_H1_sol_2          = readdlm(test_dir*res, comments=true)[:,3]
WH_WH_H1_q_given_2         = readdlm(test_dir*res, comments=true)[:,4]
WH_WH_H1_H1_given_2        = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/dev_norms_3.dat"
WH_WH_H1_q_sol_3           = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_H1_H1_sol_3          = readdlm(test_dir*res, comments=true)[:,3]
WH_WH_H1_q_given_3         = readdlm(test_dir*res, comments=true)[:,4]
WH_WH_H1_H1_given_3        = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/dev_norms_4.dat"
WH_WH_H1_q_sol_4           = readdlm(test_dir*res, comments=true)[:,2]
WH_WH_H1_H1_sol_4          = readdlm(test_dir*res, comments=true)[:,3]
WH_WH_H1_q_given_4         = readdlm(test_dir*res, comments=true)[:,4]
WH_WH_H1_H1_given_4        = readdlm(test_dir*res, comments=true)[:,5];

# %%
## CCM (SYMH_SYMH and WH_WH) L2-L2, q-q, H1-H1, and H1-q tests for solution ##

fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.09, wspace=0.09, top = 0.949, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# CCM SYMH_SYMH L2-L2 test
subplot(241) # Create the 1st fig in 2 rows and 2 columns
title(L"L^2-L^2"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_sol_0)./sqrt.(SYMH_SYMH_L2_L2_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_sol_1)./sqrt.(SYMH_SYMH_L2_L2_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_sol_2)./sqrt.(SYMH_SYMH_L2_L2_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_sol_3)./sqrt.(SYMH_SYMH_L2_L2_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CCM WH_WH L2-L2 test
subplot(245)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_sol_0)./sqrt.(WH_WH_L2_L2_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_sol_1)./sqrt.(WH_WH_L2_L2_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_sol_2)./sqrt.(WH_WH_L2_L2_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_sol_3)./sqrt.(WH_WH_L2_L2_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# CCM SYMH_SYMH q-q test
subplot(242) # Create the 1st fig in 2 rows and 2 columns
title(L"q-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_sol_0)./sqrt.(SYMH_SYMH_q_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_sol_1)./sqrt.(SYMH_SYMH_q_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_sol_2)./sqrt.(SYMH_SYMH_q_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_sol_3)./sqrt.(SYMH_SYMH_q_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=9)
################################

# CCM WH_WH q-q test
subplot(246)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_q_q_sol_0)./sqrt.(WH_WH_q_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_sol_1)./sqrt.(WH_WH_q_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_sol_2)./sqrt.(WH_WH_q_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_sol_3)./sqrt.(WH_WH_q_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

# CCM SYMH_SYMH H1-H1 test
subplot(243) # Create the 1st fig in 2 rows and 2 columns
title(L"H_1-H_1"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_sol_0)./sqrt.(SYMH_SYMH_H1_H1_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_sol_1)./sqrt.(SYMH_SYMH_H1_H1_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_sol_2)./sqrt.(SYMH_SYMH_H1_H1_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_sol_3)./sqrt.(SYMH_SYMH_H1_H1_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CCM WH_WH H1-H1 test
subplot(247)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_sol_0)./sqrt.(WH_WH_H1_H1_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_sol_1)./sqrt.(WH_WH_H1_H1_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_sol_2)./sqrt.(WH_WH_H1_H1_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_sol_3)./sqrt.(WH_WH_H1_H1_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

# CCM SYM_SYMH H1-q test
subplot(244) # Create the 1st fig in 2 rows and 2 columns
title(L"H_1-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_q_sol_0)./sqrt.(SYMH_SYMH_H1_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_q_sol_1)./sqrt.(SYMH_SYMH_H1_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_q_sol_2)./sqrt.(SYMH_SYMH_H1_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_q_sol_3)./sqrt.(SYMH_SYMH_H1_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
################################

# CCM WH_WH H1-q test
subplot(248)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_H1_q_sol_0)./sqrt.(WH_WH_H1_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_q_sol_1)./sqrt.(WH_WH_H1_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_q_sol_2)./sqrt.(WH_WH_H1_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_q_sol_3)./sqrt.(WH_WH_H1_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
## CCM (SYMH_SYMH and WH_WH) L2-L2, q-q, and H1-1 tests, for given data ##
fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.949, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# CCM SYMH_SYMH L2-L2 test
subplot(231) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_given_0)./sqrt.(SYMH_SYMH_L2_L2_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_given_1)./sqrt.(SYMH_SYMH_L2_L2_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_given_2)./sqrt.(SYMH_SYMH_L2_L2_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_L2_L2_given_3)./sqrt.(SYMH_SYMH_L2_L2_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# CCM WH_WH L2-L2 test
subplot(234)

grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_given_0)./sqrt.(WH_WH_L2_L2_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_given_1)./sqrt.(WH_WH_L2_L2_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_given_2)./sqrt.(WH_WH_L2_L2_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_L2_L2_given_3)./sqrt.(WH_WH_L2_L2_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
#legend(fontsize="15", loc=8)
###############################

# CCM SYMH_SYMH q-q test
subplot(232) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_given_0)./sqrt.(SYMH_SYMH_q_q_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_given_1)./sqrt.(SYMH_SYMH_q_q_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_given_2)./sqrt.(SYMH_SYMH_q_q_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_q_q_given_3)./sqrt.(SYMH_SYMH_q_q_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
#legend(fontsize="14", loc=9)
################################

# CCM WH_WH q-q test
subplot(235)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_q_q_given_0)./sqrt.(WH_WH_q_q_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_given_1)./sqrt.(WH_WH_q_q_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_given_2)./sqrt.(WH_WH_q_q_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_q_q_given_3)./sqrt.(WH_WH_q_q_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
###############################

# CCM SYMH_SYMH H1-H1 test
subplot(233) # Create the 1st fig in 2 rows and 2 columns
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_given_0)./sqrt.(SYMH_SYMH_H1_H1_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_given_1)./sqrt.(SYMH_SYMH_H1_H1_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_given_2)./sqrt.(SYMH_SYMH_H1_H1_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_SYMH_H1_H1_given_3)./sqrt.(SYMH_SYMH_H1_H1_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="14", loc=8)
################################

# CCM WH_WH H1-H1 test
subplot(236)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_given_0)./sqrt.(WH_WH_H1_H1_given_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_given_1)./sqrt.(WH_WH_H1_H1_given_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_given_2)./sqrt.(WH_WH_H1_H1_given_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(WH_WH_H1_H1_given_3)./sqrt.(WH_WH_H1_H1_given_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
#legend(fontsize="18", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
#initial data only
println(log2.(sqrt.(SYMH_SYMH_H1_H1_given_0)./sqrt.(SYMH_SYMH_H1_H1_given_1))[1])
println(log2.(sqrt.(SYMH_SYMH_H1_H1_given_1)./sqrt.(SYMH_SYMH_H1_H1_given_2))[1])
println(log2.(sqrt.(SYMH_SYMH_H1_H1_given_2)./sqrt.(SYMH_SYMH_H1_H1_given_3))[1])
println(log2.(sqrt.(SYMH_SYMH_H1_H1_given_3)./sqrt.(SYMH_SYMH_H1_H1_given_4))[1])

println(log2.(sqrt.(WH_WH_H1_H1_given_0)./sqrt.(WH_WH_H1_H1_given_1))[1])
println(log2.(sqrt.(WH_WH_H1_H1_given_1)./sqrt.(WH_WH_H1_H1_given_2))[1])
println(log2.(sqrt.(WH_WH_H1_H1_given_2)./sqrt.(WH_WH_H1_H1_given_3))[1])
println(log2.(sqrt.(WH_WH_H1_H1_given_3)./sqrt.(WH_WH_H1_H1_given_4))[1])

# %%
# SYMH_WH L2-L2 test
test_dir = your_dir*"SYMH_WH_noise_t20_L2_amp/norms_exact"
# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
SYMH_WH_L2_L2_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_0        = readdlm(test_dir*res, comments=true)[:,3]

#N=1
res = "/L2_1.dat"
SYMH_WH_L2_L2_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_1        = readdlm(test_dir*res, comments=true)[:,3]

#N=2
res = "/L2_2.dat"
SYMH_WH_L2_L2_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_2        = readdlm(test_dir*res, comments=true)[:,3]

#N=3
res = "/L2_3.dat"
SYMH_WH_L2_L2_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_3        = readdlm(test_dir*res, comments=true)[:,3]

#N=4
res = "/L2_4.dat"
SYMH_WH_L2_L2_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_4        = readdlm(test_dir*res, comments=true)[:,3];

# %%
# SYMH_WH q-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_WH_noise_t20_q_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_WH_q_q_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_0          = readdlm(test_dir*res, comments=true)[:,4]

#N=1
res = "/dev_norms_1.dat"
SYMH_WH_q_q_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_1          = readdlm(test_dir*res, comments=true)[:,4]

#N=2
res = "/dev_norms_2.dat"
SYMH_WH_q_q_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_2          = readdlm(test_dir*res, comments=true)[:,4]

#N=3
res = "/dev_norms_3.dat"
SYMH_WH_q_q_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_3          = readdlm(test_dir*res, comments=true)[:,4]

#N=4
res = "/dev_norms_4.dat"
SYMH_WH_q_q_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_4          = readdlm(test_dir*res, comments=true)[:,4];

# %%
# SYMH SYMH H1-H1, H1-q tests
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_WH_noise_t20_H1_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_WH_H1_q_sol_0           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_0          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_0         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_0        = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/dev_norms_1.dat"
SYMH_WH_H1_q_sol_1           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_1          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_1         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_1        = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/dev_norms_2.dat"
SYMH_WH_H1_q_sol_2           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_2          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_2         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_2        = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/dev_norms_3.dat"
SYMH_WH_H1_q_sol_3           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_3          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_3         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_3        = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/dev_norms_4.dat"
SYMH_WH_H1_q_sol_4           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_4          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_4         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_4        = readdlm(test_dir*res, comments=true)[:,5];

# %%
## CCM SYMH_WH L2-L2, q-q, H1-H1, and H1-q tests for solution ##

fig = figure("pyplot_subplot_touching",figsize=(7.5,6))
subplots_adjust(hspace=0.12, wspace=0.09, top = 0.949, bottom = 0.105, right=0.975, left=0.085)# Set the vertical spacing between axes

# L2-L2 test
subplot(221)
title(L"L^2-L^2"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_0)./sqrt.(SYMH_WH_L2_L2_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_1)./sqrt.(SYMH_WH_L2_L2_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_2)./sqrt.(SYMH_WH_L2_L2_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_3)./sqrt.(SYMH_WH_L2_L2_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=9)
###############################

# q-q test
subplot(222)
title(L"q-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_0)./sqrt.(SYMH_WH_q_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_1)./sqrt.(SYMH_WH_q_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_2)./sqrt.(SYMH_WH_q_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_3)./sqrt.(SYMH_WH_q_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=9)
###############################

# H1-H1 test
subplot(223)
title(L"H_1-H_1"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1.0:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_0)./sqrt.(SYMH_WH_H1_H1_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_1)./sqrt.(SYMH_WH_H1_H1_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_2)./sqrt.(SYMH_WH_H1_H1_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_3)./sqrt.(SYMH_WH_H1_H1_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="13", loc=9)
###############################

# H1-q test
subplot(224)
title(L"H_1-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1.0:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_0)./sqrt.(SYMH_WH_H1_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_1)./sqrt.(SYMH_WH_H1_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_2)./sqrt.(SYMH_WH_H1_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_3)./sqrt.(SYMH_WH_H1_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=8)
###############################

fig.canvas.draw() # Update the figure

# %%
# SYMH_WH L2-L2 test
test_dir = your_dir*"SYMH_B1_WH_B2_noise_t20_L2_amp/norms_exact"
# the first L2 is for the given data and the second for the solution

#N=0
res = "/L2_0.dat"
SYMH_WH_L2_L2_sol_0          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_0        = readdlm(test_dir*res, comments=true)[:,3]

#N=1
res = "/L2_1.dat"
SYMH_WH_L2_L2_sol_1          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_1        = readdlm(test_dir*res, comments=true)[:,3]

#N=2
res = "/L2_2.dat"
SYMH_WH_L2_L2_sol_2          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_2        = readdlm(test_dir*res, comments=true)[:,3]

#N=3
res = "/L2_3.dat"
SYMH_WH_L2_L2_sol_3          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_3        = readdlm(test_dir*res, comments=true)[:,3]

#N=4
res = "/L2_4.dat"
SYMH_WH_L2_L2_sol_4          = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_L2_L2_given_4        = readdlm(test_dir*res, comments=true)[:,3];

# %%
# SYMH_WH q-q test
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_B1_WH_B2_noise_t20_q_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_WH_q_q_sol_0            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_0          = readdlm(test_dir*res, comments=true)[:,4]

#N=1
res = "/dev_norms_1.dat"
SYMH_WH_q_q_sol_1            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_1          = readdlm(test_dir*res, comments=true)[:,4]

#N=2
res = "/dev_norms_2.dat"
SYMH_WH_q_q_sol_2            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_2          = readdlm(test_dir*res, comments=true)[:,4]

#N=3
res = "/dev_norms_3.dat"
SYMH_WH_q_q_sol_3            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_3          = readdlm(test_dir*res, comments=true)[:,4]

#N=4
res = "/dev_norms_4.dat"
SYMH_WH_q_q_sol_4            = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_q_q_given_4          = readdlm(test_dir*res, comments=true)[:,4];

# %%
# SYMH SYMH H1-H1, and H1-q tests
# DATA DIR; change to the directory where you have the norms saved
test_dir = your_dir*"SYMH_B1_WH_B2_noise_t20_H1_amp/dev_norms_exact"

# the first q is for the given data and the second for the solution

#N=0
res = "/dev_norms_0.dat"
SYMH_WH_H1_q_sol_0           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_0          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_0         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_0        = readdlm(test_dir*res, comments=true)[:,5]

#N=1
res = "/dev_norms_1.dat"
SYMH_WH_H1_q_sol_1           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_1          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_1         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_1        = readdlm(test_dir*res, comments=true)[:,5]

#N=2
res = "/dev_norms_2.dat"
SYMH_WH_H1_q_sol_2           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_2          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_2         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_2        = readdlm(test_dir*res, comments=true)[:,5]

#N=3
res = "/dev_norms_3.dat"
SYMH_WH_H1_q_sol_3           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_3          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_3         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_3        = readdlm(test_dir*res, comments=true)[:,5]

#N=4
res = "/dev_norms_4.dat"
SYMH_WH_H1_q_sol_4           = readdlm(test_dir*res, comments=true)[:,2]
SYMH_WH_H1_H1_sol_4          = readdlm(test_dir*res, comments=true)[:,3]
SYMH_WH_H1_q_given_4         = readdlm(test_dir*res, comments=true)[:,4]
SYMH_WH_H1_H1_given_4        = readdlm(test_dir*res, comments=true)[:,5];

#tt_0                           = readdlm(test_dir*res, comments=true)[:,1]

# %%
## CCM SYMH_B1_WH_B2 L2-L2, q-q, H1-H1, and H1-q tests for solution; both C_exact and norms themselves (not their ratio) ##

fig = figure("pyplot_subplot_touching",figsize=(15,6))
subplots_adjust(hspace=0.08, wspace=0.09, top = 0.949, bottom = 0.105, right=0.99, left=0.04)# Set the vertical spacing between axes

# L2-L2 test C_exact
subplot(241) # Create the 1st fig in 2 rows and 2 columns
title(L"L^2-L^2"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(0.0:1:3.0,fontsize="18")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_0)./sqrt.(SYMH_WH_L2_L2_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{L^2}\,/\,||\mathbf{u}_{h_1}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_1)./sqrt.(SYMH_WH_L2_L2_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{L^2}\,/\,||\mathbf{u}_{h_2}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_2)./sqrt.(SYMH_WH_L2_L2_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{L^2}\,/ \,||\mathbf{u}_{h_3}||_{L^2}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_L2_L2_sol_3)./sqrt.(SYMH_WH_L2_L2_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{L^2}\,/ \,||\mathbf{u}_{h_4}||_{L^2}\right)}")
# LEGEND
legend(fontsize="13", loc=1)
################################

# L2 norm of solution
subplot(245)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks([10^(-2),10^2,10^6,10^10],fontsize="12")
ylim(10^(-2),10^10)
yscale("log")
#plot
plot(tt_0, sqrt.(SYMH_WH_L2_L2_sol_0), linestyle=":" , linewidth=5,  
label=L"||\mathbf{u}_{h_0}||_{L^2}")
plot(tt_0, sqrt.(SYMH_WH_L2_L2_sol_1), linestyle="-." , linewidth=4.5,  
label=L"||\mathbf{u}_{h_1}||_{L^2}")
plot(tt_0, sqrt.(SYMH_WH_L2_L2_sol_2), linestyle="--" , linewidth=4.5,  
label=L"||\mathbf{u}_{h_2}||_{L^2}")
plot(tt_0, sqrt.(SYMH_WH_L2_L2_sol_3), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_3}||_{L^2}")
plot(tt_0, sqrt.(SYMH_WH_L2_L2_sol_4), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_4}||_{L^2}")
legend(fontsize="13", loc=2)
###############################

# C_exact q-q test
subplot(242) # Create the 1st fig in 2 rows and 2 columns
title(L"q-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_0)./sqrt.(SYMH_WH_q_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_1)./sqrt.(SYMH_WH_q_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_2)./sqrt.(SYMH_WH_q_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_q_q_sol_3)./sqrt.(SYMH_WH_q_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
#LEGEND
legend(fontsize="13", loc=1)
################################

# q norm of solution
subplot(246)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(fontsize="0")
ylim(10^(-2),10^10)
yscale("log")
#plot
plot(tt_0, sqrt.(SYMH_WH_q_q_sol_0), linestyle=":" , linewidth=5,  
label=L"||\mathbf{u}_{h_0}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_q_q_sol_1), linestyle="-." , linewidth=4.5,  
label=L"||\mathbf{u}_{h_1}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_q_q_sol_2), linestyle="--" , linewidth=4.5,  
label=L"||\mathbf{u}_{h_2}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_q_q_sol_3), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_3}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_q_q_sol_4), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_4}||_{q}")
legend(fontsize="13", loc=2)
###############################

# C_exact H1-H1 test
subplot(243) # Create the 1st fig in 2 rows and 2 columns
title(L"H_1-H_1"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_0)./sqrt.(SYMH_WH_H1_H1_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{H_1}\,/\,||\mathbf{u}_{h_1}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_1)./sqrt.(SYMH_WH_H1_H1_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{H_1}\,/\,||\mathbf{u}_{h_2}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_2)./sqrt.(SYMH_WH_H1_H1_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{H_1}\,/ \,||\mathbf{u}_{h_3}||_{H_1}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_H1_sol_3)./sqrt.(SYMH_WH_H1_H1_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{H_1}\,/ \,||\mathbf{u}_{h_4}||_{H_1}\right)}")
# LEGEND
legend(fontsize="13", loc=1)
################################

# H1 norm of solution
subplot(247)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(fontsize="0")
ylim(10^(-2),10^10)
yscale("log")
#plot
plot(tt_0, sqrt.(SYMH_WH_H1_H1_sol_0), linestyle=":" , linewidth=5,  
label=L"||\mathbf{u}_{h_0}||_{H_1}")
plot(tt_0, sqrt.(SYMH_WH_H1_H1_sol_1), linestyle="-." , linewidth=4.5,  
label=L"||\mathbf{u}_{h_1}||_{H_1}")
plot(tt_0, sqrt.(SYMH_WH_H1_H1_sol_2), linestyle="--" , linewidth=4.5,  
label=L"||\mathbf{u}_{h_2}||_{H_1}")
plot(tt_0, sqrt.(SYMH_WH_H1_H1_sol_3), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_3}||_{H_1}")
plot(tt_0, sqrt.(SYMH_WH_H1_H1_sol_4), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_4}||_{H_1}")
legend(fontsize="13", loc=2)
###############################

# C_exact H1-q test
subplot(244) # Create the 1st fig in 2 rows and 2 columns
title(L"H_1-q"*" test", fontsize=15)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="0") # Set the x-tick range and step size
xlabel("time",fontsize="0")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="25")
yticks(0.0:1:3.0,fontsize="0")
ylim(0.0,3)
#plot
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_0)./sqrt.(SYMH_WH_H1_q_sol_1)), linestyle=":" , linewidth=5,  
label=L"\log_2{\left(||\mathbf{u}_{h_0}||_{q}\,/\,||\mathbf{u}_{h_1}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_1)./sqrt.(SYMH_WH_H1_q_sol_2)), linestyle="-.", linewidth=4.5, 
label=L"\log_2{\left(||\mathbf{u}_{h_1}||_{q}\,/\,||\mathbf{u}_{h_2}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_2)./sqrt.(SYMH_WH_H1_q_sol_3)), linestyle="--", linewidth=4.5,
label=L"\log_2{\left(||\mathbf{u}_{h_2}||_{q}\,/ \,||\mathbf{u}_{h_3}||_{q}\right)}")
plot(tt_0, log2.(sqrt.(SYMH_WH_H1_q_sol_3)./sqrt.(SYMH_WH_H1_q_sol_4)), linestyle="-" , linewidth=4.2,
label=L"\log_2{\left(||\mathbf{u}_{h_3}||_{q}\,/ \,||\mathbf{u}_{h_4}||_{q}\right)}")
# LEGEND
legend(fontsize="13", loc=1)
################################

# q norm of solution
subplot(248)
grid("on")
#x-axis
xlim(0.0,20.0) # Set the x-limits
xticks(0.0:5:20.0,fontsize="18") # Set the x-tick range and step size
xlabel("time",fontsize="20")
#y-axis
#ylabel(L"\mathcal{C}_{exact}",fontsize="20")
yticks(fontsize="0")
ylim(10^(-2),10^10)
yscale("log")
#plot
plot(tt_0, sqrt.(SYMH_WH_H1_q_sol_0), linestyle=":" , linewidth=5,  
label=L"||\mathbf{u}_{h_0}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_H1_q_sol_1), linestyle="-." , linewidth=4.5,  
label=L"||\mathbf{u}_{h_1}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_H1_q_sol_2), linestyle="--" , linewidth=4.5,  
label=L"||\mathbf{u}_{h_2}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_H1_q_sol_3), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_3}||_{q}")
plot(tt_0, sqrt.(SYMH_WH_H1_q_sol_4), linestyle="-" , linewidth=4.2,  
label=L"||\mathbf{u}_{h_4}||_{q}")
legend(fontsize="13", loc=2)
###############################

fig.canvas.draw() # Update the figure
